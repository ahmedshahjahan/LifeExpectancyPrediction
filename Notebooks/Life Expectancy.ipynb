# %%
import pandas as pd
dataset=pd.read_csv("Life_Expectancy_Data.csv")
dataset.head(20)
# Out:
#         Country  Year      Status  Life expectancy   Adult Mortality  \
# 0   Afghanistan  2015  Developing              65.0            263.0
# 1   Afghanistan  2014  Developing              59.9            271.0
# 2   Afghanistan  2013  Developing              59.9            268.0
# 3   Afghanistan  2012  Developing              59.5            272.0
# 4   Afghanistan  2011  Developing              59.2            275.0
# 5   Afghanistan  2010  Developing              58.8            279.0
# 6   Afghanistan  2009  Developing              58.6            281.0
# 7   Afghanistan  2008  Developing              58.1            287.0
# 8   Afghanistan  2007  Developing              57.5            295.0
# 9   Afghanistan  2006  Developing              57.3            295.0
# 10  Afghanistan  2005  Developing              57.3            291.0
# 11  Afghanistan  2004  Developing              57.0            293.0
# 12  Afghanistan  2003  Developing              56.7            295.0
# 13  Afghanistan  2002  Developing              56.2              3.0
# 14  Afghanistan  2001  Developing              55.3            316.0
# 15  Afghanistan  2000  Developing              54.8            321.0
# 16      Albania  2015  Developing              77.8             74.0
# 17      Albania  2014  Developing              77.5              8.0
# 18      Albania  2013  Developing              77.2             84.0
# 19      Albania  2012  Developing              76.9             86.0
#
#     infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0              62     0.01               71.279624         65.0      1154
# 1              64     0.01               73.523582         62.0       492
# 2              66     0.01               73.219243         64.0       430
# 3              69     0.01               78.184215         67.0      2787
# 4              71     0.01                7.097109         68.0      3013
# 5              74     0.01               79.679367         66.0      1989
# 6              77     0.01               56.762217         63.0      2861
# 7              80     0.03               25.873925         64.0      1599
# 8              82     0.02               10.910156         63.0      1141
# 9              84     0.03               17.171518         64.0      1990
# 10             85     0.02                1.388648         66.0      1296
# 11             87     0.02               15.296066         67.0       466
# 12             87     0.01               11.089053         65.0       798
# 13             88     0.01               16.887351         64.0      2486
# 14             88     0.01               10.574728         63.0      8762
# 15             88     0.01               10.424960         62.0      6532
# 16              0     4.60              364.975229         99.0         0
# 17              0     4.51              428.749067         98.0         0
# 18              0     4.76              430.876979         99.0         0
# 19              0     5.14              412.443356         99.0         9
#
#     ...  Polio  Total expenditure  Diphtheria    HIV/AIDS          GDP  \
# 0   ...    6.0               8.16         65.0        0.1   584.259210
# 1   ...   58.0               8.18         62.0        0.1   612.696514
# 2   ...   62.0               8.13         64.0        0.1   631.744976
# 3   ...   67.0               8.52         67.0        0.1   669.959000
# 4   ...   68.0               7.87         68.0        0.1    63.537231
# 5   ...   66.0               9.20         66.0        0.1   553.328940
# 6   ...   63.0               9.42         63.0        0.1   445.893298
# 7   ...   64.0               8.33         64.0        0.1   373.361116
# 8   ...   63.0               6.73         63.0        0.1   369.835796
# 9   ...   58.0               7.43         58.0        0.1   272.563770
# 10  ...   58.0               8.70         58.0        0.1    25.294130
# 11  ...    5.0               8.79          5.0        0.1   219.141353
# 12  ...   41.0               8.82         41.0        0.1   198.728544
# 13  ...   36.0               7.76         36.0        0.1   187.845950
# 14  ...   35.0               7.80         33.0        0.1   117.496980
# 15  ...   24.0               8.20         24.0        0.1   114.560000
# 16  ...   99.0               6.00         99.0        0.1  3954.227830
# 17  ...   98.0               5.88         98.0        0.1  4575.763787
# 18  ...   99.0               5.66         99.0        0.1  4414.723140
# 19  ...   99.0               5.59         99.0        0.1  4247.614380
#
#     Population   thinness  1-19 years   thinness 5-9 years  \
# 0   33736494.0                   17.2                 17.3
# 1     327582.0                   17.5                 17.5
# 2   31731688.0                   17.7                 17.7
# 3    3696958.0                   17.9                 18.0
# 4    2978599.0                   18.2                 18.2
# 5    2883167.0                   18.4                 18.4
# 6     284331.0                   18.6                 18.7
# 7    2729431.0                   18.8                 18.9
# 8   26616792.0                   19.0                 19.1
# 9    2589345.0                   19.2                 19.3
# 10    257798.0                   19.3                 19.5
# 11  24118979.0                   19.5                 19.7
# 12   2364851.0                   19.7                 19.9
# 13  21979923.0                   19.9                  2.2
# 14   2966463.0                    2.1                  2.4
# 15    293756.0                    2.3                  2.5
# 16     28873.0                    1.2                  1.3
# 17    288914.0                    1.2                  1.3
# 18    289592.0                    1.3                  1.4
# 19      2941.0                    1.3                  1.4
#
#     Income composition of resources  Schooling
# 0                             0.479       10.1
# 1                             0.476       10.0
# 2                             0.470        9.9
# 3                             0.463        9.8
# 4                             0.454        9.5
# 5                             0.448        9.2
# 6                             0.434        8.9
# 7                             0.433        8.7
# 8                             0.415        8.4
# 9                             0.405        8.1
# 10                            0.396        7.9
# 11                            0.381        6.8
# 12                            0.373        6.5
# 13                            0.341        6.2
# 14                            0.340        5.9
# 15                            0.338        5.5
# 16                            0.762       14.2
# 17                            0.761       14.2
# 18                            0.759       14.2
# 19                            0.752       14.2
#
# [20 rows x 22 columns]

# %%
dataset.shape
# Out:
# (2938, 22)

# %%
dataset.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=2938, step=1)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15   HIV/AIDS                        2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18   thinness  1-19 years            2904 non-null   float64
#  19   thinness 5-9 years              2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB

# %%
dataset.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
crime_data=pd.read_csv('chicago_crime_data.csv')
crime_data.head()
# Out:
#                      Date                 Block Primary Type  \
# 0  05/23/2016 05:35:00 PM   024XX W DIVISION ST      ASSAULT
# 1  03/26/2016 08:20:00 PM     019XX W HOWARD ST     BURGLARY
# 2  04/25/2016 03:05:00 PM       001XX W 79TH ST        THEFT
# 3  04/26/2016 05:30:00 PM      010XX N PINE AVE      BATTERY
# 4  06/19/2016 01:15:00 AM  027XX W AUGUSTA BLVD      BATTERY
#
#            Description Location Description  Arrest  Domestic  District
# 0               SIMPLE               STREET   False      True        14
# 1       FORCIBLE ENTRY   SMALL RETAIL STORE   False     False        24
# 2         RETAIL THEFT     DEPARTMENT STORE    True     False         6
# 3               SIMPLE             SIDEWALK   False     False        15
# 4  AGGRAVATED: HANDGUN             SIDEWALK   False     False        12

# %%
# crime_data['Primary Type'].unique()
crime_data['Description'].unique()
# Out:
# array(['SIMPLE', 'FORCIBLE ENTRY', 'RETAIL THEFT', 'AGGRAVATED: HANDGUN',
#        'DOMESTIC BATTERY SIMPLE', 'RECKLESS CONDUCT',
#        'TO CITY OF CHICAGO PROPERTY', 'ARMED: HANDGUN',
#        'AGGRAVATED:KNIFE/CUTTING INSTR',
#        'FINANCIAL IDENTITY THEFT $300 AND UNDER', 'ILLEGAL USE CASH CARD',
#        'TELEPHONE THREAT', 'TO PROPERTY',
#        'HARASSMENT BY ELECTRONIC MEANS', 'NON-AGGRAVATED',
#        'POSS: HEROIN(BRN/TAN)', '$500 AND UNDER', 'AUTOMOBILE',
#        'CREDIT CARD FRAUD', 'TO VEHICLE', 'OTHER OFFENSE',
#        'FINANCIAL IDENTITY THEFT OVER $ 300', 'FROM BUILDING',
#        'LIQUOR LICENSE VIOLATION', 'OVER $500', 'TO RESIDENCE',
#        'PRO EMP HANDS NO/MIN INJURY', 'UNLAWFUL POSS OF HANDGUN',
#        'UNLAWFUL ENTRY', 'SEX ASSLT OF CHILD BY FAM MBR',
#        'PURSE-SNATCHING', 'AGGRAVATED: OTHER DANG WEAPON',
#        'AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST',
#        'STRONGARM - NO WEAPON',
#        'AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON',
#        'POSS: SYNTHETIC DRUGS', 'POSS: CANNABIS 30GMS OR LESS',
#        'OTHER VIOLATION', 'OTHER VEHICLE OFFENSE', 'POSS: HEROIN(WHITE)',
#        'BOGUS CHECK', 'HARASSMENT BY TELEPHONE', 'ATTEMPT FORCIBLE ENTRY',
#        'COUNTERFEITING DOCUMENT', 'POCKET-PICKING',
#        'SOLICIT NARCOTICS ON PUBLICWAY', 'THEFT OF LABOR/SERVICES',
#        'MANU/DELIVER:CRACK', 'VIOLATE ORDER OF PROTECTION',
#        'FRAUD OR CONFIDENCE GAME', 'HOME INVASION',
#        'AGGRAVATED VEHICULAR HIJACKING', 'TO LAND', 'CHILD ABANDONMENT',
#        'CRIMINAL DEFACEMENT', 'POSS: CRACK',
#        'ATTEMPT POSSESSION NARCOTICS', 'GAME/DICE',
#        'AGGRAVATED: OTHER FIREARM', 'POSS: CANNABIS MORE THAN 30GMS',
#        'THEFT/RECOVERY: AUTOMOBILE', 'ARMED:KNIFE/CUTTING INSTRUMENT',
#        'OTHER', 'POSS: HALLUCINOGENS', 'ENDANGERING LIFE/HEALTH CHILD',
#        'TO STATE SUP LAND', 'CHILD ABUSE', 'LICENSE VIOLATION',
#        'MANU/DELIVER: HEROIN (WHITE)', 'BOMB THREAT',
#        'SOLICIT ON PUBLIC WAY', 'ATTEMPT: ARMED-OTHER DANG WEAP',
#        'AGGRAVATED FINANCIAL IDENTITY THEFT', 'POSS: COCAINE',
#        'VEHICULAR HIJACKING', 'PUBLIC INDECENCY',
#        'AGG PO HANDS NO/MIN INJURY', 'AGG PRO.EMP: OTHER DANG WEAPON',
#        'ATT: AUTOMOBILE', 'ATTEMPT: ARMED-KNIFE/CUT INSTR',
#        'PAROLE VIOLATION', 'ATTEMPT - FINANCIAL IDENTITY THEFT',
#        'AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY',
#        'FALSE/STOLEN/ALTERED TRP', 'CRIMINAL SEXUAL ABUSE',
#        'MANU/DEL:CANNABIS 10GM OR LESS', 'AGGRAVATED',
#        'COUNTERFEIT CHECK', 'THEFT OF LOST/MISLAID PROP',
#        'POSSESSION OF DRUG EQUIPMENT', 'FIRST DEGREE MURDER',
#        'ATTEMPT: STRONGARM-NO WEAPON', 'CHILD ABDUCTION/STRANGER',
#        'VEHICLE TITLE/REG OFFENSE', 'AGG CRIM SEX ABUSE FAM MEMBER',
#        'AGG: HANDS/FIST/FEET SERIOUS INJURY', 'FOUND SUSPECT NARCOTICS',
#        'ATTEMPT: ARMED-HANDGUN', 'AGGRAVATED OF A CHILD', 'ATTEMPT THEFT',
#        'SEX OFFENDER: FAIL REG NEW ADD', 'FORGERY',
#        'OTHER CRIME AGAINST PERSON', 'CRIM SEX ABUSE BY FAM MEMBER',
#        'CHILD ABDUCTION', 'MANU/DEL:CANNABIS OVER 10 GMS',
#        'ATTEMPT: AGGRAVATED', 'SEX OFFENDER: FAIL TO REGISTER', 'BY FIRE',
#        'GUN OFFENDER: DUTY TO REGISTER', 'MANU/DELIVER:PCP',
#        'AGG CRIMINAL SEXUAL ABUSE', 'GUN OFFENDER: ANNUAL REGISTRATION',
#        'VIO BAIL BOND: DOM VIOLENCE', 'RECKLESS FIREARM DISCHARGE',
#        'UNLAWFUL POSS OTHER FIREARM',
#        'MANU/POSS. W/INTENT TO DELIVER: SYNTHETIC MARIJUANA', 'PREDATORY',
#        'POSS: PCP', 'ARMED: OTHER DANGEROUS WEAPON',
#        'RESIST/OBSTRUCT/DISARM OFFICER', 'ATT CRIM SEXUAL ABUSE',
#        'UNLAWFUL RESTRAINT', 'THEFT BY LESSEE,MOTOR VEH',
#        'COMPUTER FRAUD', 'AGGRAVATED: OTHER', 'ARSON THREAT',
#        'FALSE POLICE REPORT', 'POSS: BARBITUATES',
#        'TRUCK, BUS, MOTOR HOME', 'OTHER CRIME INVOLVING PROPERTY',
#        'ANIMAL ABUSE/NEGLECT', 'FORFEIT PROPERTY',
#        'OBSTRUCTING IDENTIFICATION', 'PUBLIC DEMONSTRATION',
#        'GAME/AMUSEMENT DEVICE', 'POS: HYPODERMIC NEEDLE', 'MOB ACTION',
#        'CYCLE, SCOOTER, BIKE W-VIN', 'UNLAWFUL POSS AMMUNITION',
#        'EXTORTION', 'DELIVERY CONTAINER THEFT',
#        'AGGRAVATED PO: OTHER DANG WEAP', 'INTERFERENCE JUDICIAL PROCESS',
#        'AGG: HANDS/FIST/FEET NO/MINOR INJURY', 'CHILD PORNOGRAPHY',
#        'ATTEMPT NON-AGGRAVATED', 'MANU/DELIVER: HALLUCINOGEN',
#        'POSS FIREARM/AMMO:NO FOID CARD', 'AGGRAVATED PO: HANDGUN',
#        'INDECENT SOLICITATION/ADULT', 'INTIMIDATION',
#        'VIOLATION OF CIVIL NO CONTACT ORDER',
#        'INDECENT SOLICITATION/CHILD', 'UNLAWFUL USE/SALE AIR RIFLE',
#        'UNAUTHORIZED VIDEOTAPING', 'OBSTRUCTING JUSTICE',
#        'SOLICIT FOR PROSTITUTE', 'OTHER WEAPONS VIOLATION',
#        'UNLAWFUL USE HANDGUN', 'AGGRAVATED DOMESTIC BATTERY: HANDGUN',
#        'FINAN EXPLOIT-ELDERLY/DISABLED',
#        'THEFT/RECOVERY: TRUCK,BUS,MHOME', 'ATTEMPT ARSON',
#        'OBSTRUCTING SERVICE', 'LIBRARY VANDALISM',
#        'AGGRAVATED OF A SENIOR CITIZEN', 'LOST PASSPORT',
#        'SALE/DIST OBSCENE MAT TO MINOR',
#        'VIOLATION OF STALKING NO CONTACT ORDER',
#        'AGG PRO.EMP:KNIFE/CUTTING INST', 'ILLEGAL POSSESSION BY MINOR',
#        'ILLEGAL CONSUMPTION BY MINOR', 'UNLAWFUL USE OTHER DANG WEAPON',
#        'EMBEZZLEMENT', 'ESCAPE', 'MANU/DELIVER:SYNTHETIC DRUGS',
#        'OBSCENE TELEPHONE CALLS', 'SELL/GIVE/DEL LIQUOR TO MINOR',
#        'OBSCENE MATTER', 'VIOLENT OFFENDER: ANNUAL REGISTRATION',
#        'AGGRAVATED PO:KNIFE/CUT INSTR', 'SEXUAL EXPLOITATION OF A CHILD',
#        'STOLEN PROP: BUY/RECEIVE/POS.',
#        'THEFT/RECOVERY: CYCLE, SCOOTER, BIKE W-VIN',
#        'ALTER/FORGE PRESCRIPTION', 'ARMED: OTHER FIREARM', 'PANDERING',
#        'ATTEMPT AGG: KNIFE/CUT INSTR', 'ATTEMPT: ARMED-OTHER FIREARM',
#        'KIDNAPPING', 'AGG PRO EMP HANDS SERIOUS INJ',
#        'UNLAWFUL USE OTHER FIREARM', 'DECEPTIVE COLLECTION PRACTICES',
#        'TO STATE SUP PROP', 'AGG PO HANDS ETC SERIOUS INJ',
#        'ATTEMPT AGG: OTHER', 'MANU/DELIVER: HEROIN(BRN/TAN)',
#        'IMPERSONATION', 'PROHIBITED PLACES',
#        'OTHER ARSON/EXPLOSIVE INCIDENT', 'OBSCENITY',
#        'POSS: LOOK-ALIKE DRUGS', 'VIOLENT OFFENDER: DUTY TO REGISTER',
#        'AGG SEX ASSLT OF CHILD FAM MBR', 'CYBERSTALKING',
#        'AGG PRO.EMP: HANDGUN', 'FOID - REVOCATION',
#        'POSS: METHAMPHETAMINES', 'CYCLE, SCOOTER, BIKE NO VIN',
#        'PEEPING TOM', 'UNLAWFUL SALE HANDGUN', 'MONEY LAUNDERING',
#        'VIOLENT OFFENDER: FAIL TO REGISTER NEW ADDRESS',
#        'CRIMINAL DRUG CONSPIRACY', 'CONTRIBUTE DELINQUENCY OF A CHILD',
#        'MANU/DELIVER:BARBITUATES', 'DEL CONT SUBS TO PERSON <18',
#        'FROM COIN-OP MACHINE/DEVICE', 'PROBATION VIOLATION'], dtype=object)

# %%
crime_data.shape
# Out:
# (15000, 8)

# %%
crime_data.columns
# Out:
# Index(['Date', 'Block', 'Primary Type', 'Description', 'Location Description',
#        'Arrest', 'Domestic', 'District'],
#       dtype='object')
